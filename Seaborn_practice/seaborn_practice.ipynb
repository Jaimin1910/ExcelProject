# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./insurance.csv')

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df_avg_exp_age = df.groupby('age')['expenses'].mean().to_frame().reset_index()

# %%
df_avg_exp_age.head()
# Out:
#    age      expenses
# 0   18   7086.217971
# 1   19   9747.909706
# 2   20  10159.697931
# 3   21   4730.464286
# 4   22  10012.932857

# %%
sns.lineplot(x='age', y='expenses', data=df_avg_exp_age, ci=None)
plt.xlabel('age')
plt.ylabel('expenses')
plt.title('Avg Expense Vs Age')
plt.show()

# %%
df_premium_region = df.groupby('region')['expenses'
                                        ].mean().to_frame().reset_index()

# %%
df_premium_region.head()
# Out:
#       region      expenses
# 0  northeast  13406.384691
# 1  northwest  12417.575169
# 2  southeast  14735.411538
# 3  southwest  12346.937908

# %%
sns.barplot(x='region', y='expenses', data=df_premium_region)
plt.show()

# %%
df_premium_region_sex = df.groupby(['region', 'sex'])['expenses'
                                        ].mean().to_frame().reset_index()

# %%
df_premium_region_sex
# Out:
#       region     sex      expenses
# 0  northeast  female  12953.203106
# 1  northeast    male  13854.005767
# 2  northwest  female  12479.870244
# 3  northwest    male  12354.119317
# 4  southeast  female  13499.669257
# 5  southeast    male  15879.617354
# 6  southwest  female  11274.411667
# 7  southwest    male  13412.884233

# %%
sns.barplot(x='region', y='expenses', hue='sex', data=df_premium_region_sex)
plt.show()

# %%
sns.displot(x='expenses', data=df, kind='hist')
plt.show()

# %%
sns.displot(x='expenses', data=df, kind='kde')
plt.show()

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
sns.boxplot(x='region', y='bmi', data=df)
plt.show()

# %%
sns.violinplot(x='bmi', y='region', data=df)
plt.show()

# %%
sns.relplot(x='age', y='bmi', data=df, kind='scatter', hue='sex')
plt.show()

# %%
sns.relplot(x='age', y='bmi', data=df, kind='line', hue='sex')
plt.show()

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
plt.figure(figsize=(10, 10))
sns.relplot(x='age', y='expenses', size='bmi', data=df, alpha=0.2)
plt.show()

# %%
sns.relplot(x='age', y='expenses', size='bmi',
            row='sex', col='region', data=df, alpha=0.5)
plt.show()

# %%
sns.catplot(x='region', y='bmi', data=df)
plt.show()

# %%
ax_1 = plt.subplot(1, 2, 1)
sns.catplot(x='region', y='bmi', data=df, kind='point', axes=ax_1)

ax_2 = plt.subplot(1, 2, 2)
sns.catplot(x='region', y='expenses', data=df, kind='point', ax=ax_2)

plt.show()
# Out:
# C:\Users\Huzefa\Anaconda3\Lib\site-packages\seaborn\categorical.py:3762: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# C:\Users\Huzefa\Anaconda3\Lib\site-packages\seaborn\categorical.py:3762: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
sns.catplot(x='region', y='bmi', data=df, kind='point')
plt.show()

# %%
sns.catplot(x='region', y='expenses', data=df, kind='point')
plt.show()

# %%
sns.pairplot(df)
plt.show()
